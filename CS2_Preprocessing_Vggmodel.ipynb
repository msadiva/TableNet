# %%
### importing necessary packages 

import pandas as pd
import numpy as np
import tensorflow as tf
import os
from sklearn.model_selection import train_test_split
import cv2
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import UpSampling2D, MaxPooling2D, Concatenate, Input, Add, Dense, Activation, BatchNormalization, Flatten, Conv2D, Conv2DTranspose, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint
#from google.colab import drive
import seaborn as sns
import pytesseract
from PIL import Image, ImageEnhance, ImageFilter

# %%
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
os.chdir('D:/case study 2')

# %%
os.listdir()
# Out:
# ['.idea',
#  'app.py',
#  'best_model_cs2_final_vgg.h5',
#  'templates',
#  'test_image.jpeg',
#  'vgg_compressed.tflite']

# %%
### importing our dataset

dataset = pd.read_csv('dataset.csv')

dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 494 entries, 0 to 493
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     494 non-null    int64
#  1   Unnamed: 0.1   494 non-null    int64
#  2   image          494 non-null    object
#  3   mask           494 non-null    object
#  4   column_output  494 non-null    object
#  5   table_output   494 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 23.3+ KB

# %%
dataset.drop(['Unnamed: 0.1'], axis = 1, inplace = True)

# %%
dataset.drop(['Unnamed: 0'], axis = 1, inplace = True)

# %%
dataset.head()
# Out:
#                                        image  ...                                       table_output
# 0   Case study 2/images/10.1.1.1.2006_3.jpeg  ...  Case study 2/output/10.1.1.1.2006_3/table_mask...
# 1  Case study 2/images/10.1.1.1.2013_63.jpeg  ...  Case study 2/output/10.1.1.1.2013_63/table_mas...
# 2  Case study 2/images/10.1.1.1.2013_64.jpeg  ...  Case study 2/output/10.1.1.1.2013_64/table_mas...
# 3   Case study 2/images/10.1.1.1.2014_4.jpeg  ...  Case study 2/output/10.1.1.1.2014_4/table_mask...
# 4   Case study 2/images/10.1.1.1.2014_6.jpeg  ...  Case study 2/output/10.1.1.1.2014_6/table_mask...
#
# [5 rows x 4 columns]

# %% [markdown]
# ### For data pre processing we have to -
# #### Resize our images to 1024*1024
# #### Normalize the image

# %%
### reference - https://www.tensorflow.org/api_docs/python/tf/io/read_file

def load_image(image, col_mask, tab_mask):
    '''this function will resize the images to 1024*1024
       and normalize every pixel by dividing by 255'''
    image = tf.io.read_file(image)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, [1024,1024])
    image = tf.cast(image, tf.float32) / 255.0
    col_mask = tf.io.read_file(col_mask)
    col_mask = tf.image.decode_jpeg(col_mask, channels=1)
    col_mask = tf.image.resize(col_mask, [1024,1024])
    col_mask = tf.cast(col_mask, tf.float32) / 255.0 
    tab_mask = tf.io.read_file(tab_mask)
    tab_mask = tf.image.decode_jpeg(tab_mask, channels = 1)
    tab_mask = tf.image.resize(tab_mask, [1024,1024])
    tab_mask = tf.cast(tab_mask, tf.float32) / 255.0
    return image, {"column_mask" : col_mask, "table_mask" : tab_mask}

# %%
#os.chdir('D:/Applied AI/')
os.chdir('/content/drive/My Drive/')
for i in range(3) :
    image = dataset['image'][i]
    col_mask = dataset['column_output'][i]
    tab_mask = dataset['table_output'][i]
    image, mask = load_image(image, col_mask, tab_mask)
    plt.figure(figsize = (10,6))
    plt.subplot(131)
    plt.title("Scanned preprocessed image")
    plt.imshow(tf.keras.preprocessing.image.array_to_img(image))
    plt.subplot(132)
    plt.title("Preprocessed column mask")
    plt.imshow(tf.keras.preprocessing.image.array_to_img(mask["column_mask"]))
    plt.subplot(133)
    plt.title("Preprocessed table mask")
    plt.imshow(tf.keras.preprocessing.image.array_to_img(mask["table_mask"]))
    plt.show()

# %% [markdown]
# ### TableNet Model

# %%
#X_input = Input(shape = (1024,1024,3), name = "input_layer")

### importing VGG-19 architecture as our encoder
vgg_19 = tf.keras.applications.VGG19(include_top = False, weights = 'imagenet', input_shape = (1024,1024,3))

# %%
vgg_19.summary()
# Out:
# Model: "vgg19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 1024, 1024, 3)]   0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 1024, 1024, 64)    1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 1024, 1024, 64)    36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 512, 512, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 512, 512, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 512, 512, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 256, 256, 128)     0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 256, 256, 256)     295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 256, 256, 256)     590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 256, 256, 256)     590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 256, 256, 256)     590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 128, 128, 256)     0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 128, 128, 512)     1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 128, 128, 512)     2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 128, 128, 512)     2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 128, 128, 512)     2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 64, 64, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 64, 64, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 64, 64, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 64, 64, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 64, 64, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 32, 32, 512)       0
# =================================================================
# Total params: 20,024,384
# Trainable params: 20,024,384
# Non-trainable params: 0
# _________________________________________________________________

# %%
vgg_19.get_layer('block4_pool').output
# Out:
# <tf.Tensor 'block4_pool_3/Identity:0' shape=(None, 64, 64, 512) dtype=float32>

# %% [markdown]
# ### We need block 3 pool and block 4 pool for our table net architecture

# %%
class table_decoder(tf.keras.layers.Layer):
    def __init__(self, name = "table_mask"):
        super().__init__(name = name)
        self.conv1 = Conv2D(kernel_size = 1, filters = 256, kernel_initializer = tf.keras.initializers.glorot_uniform(seed = 0))
        self.upsamp1 = UpSampling2D(size = (2,2), interpolation = 'bilinear')
        self.concat1 = Concatenate(axis = -1)
        self.upsamp2 = UpSampling2D(size = (2,2), interpolation = 'bilinear')
        self.upsamp3 = UpSampling2D(size = (4,4), interpolation = 'bilinear')
        self.concat2 = Concatenate(axis = -1)
        self.convtrans = Conv2DTranspose(filters = 2, kernel_size = (2,2),strides = 2)
        
    def call(self, X):
        x_inp, block3, block4 = X[0], X[1], X[2]
        x_con = self.conv1(x_inp)
        x_con = self.upsamp1(x_con)
        x_con = self.concat1([x_con, block4])
        x_con = self.upsamp2(x_con)
        x_con = self.concat2([x_con, block3])
        x_con = self.upsamp3(x_con)
        x_con = self.convtrans(x_con)
        
        return x_con

# %%
class column_decoder(tf.keras.layers.Layer):
    def __init__(self, name = "column_mask"):
        super().__init__(name = name)
        self.conv1 = Conv2D(kernel_size = 1, filters = 256, activation = 'relu', kernel_initializer = tf.keras.initializers.glorot_uniform(seed=0))
        self.drop = Dropout(rate = 0.8)
        self.conv2 = Conv2D(kernel_size = 1, filters = 256, kernel_initializer = tf.keras.initializers.glorot_uniform(seed=0))
        self.upsamp1 = UpSampling2D(size = (2,2), interpolation = 'bilinear')
        self.concat1 = Concatenate(axis = -1)
        self.upsamp2 = UpSampling2D(size = (2,2), interpolation = 'bilinear')
        self.concat2 = Concatenate(axis = -1)
        self.upsamp3 = UpSampling2D(size = (4,4), interpolation = 'bilinear')
        self.convtrans = Conv2DTranspose(filters = 2, kernel_size = (2,2), strides = 2)
        
    def call(self, X):
        x_inp, block3, block4 = X[0], X[1], X[2]
        x_con = self.conv1(x_inp)
        x_con = self.drop(x_con)
        x_con = self.conv2(x_con)
        x_con = self.upsamp1(x_con)
        x_con = self.concat1([x_con, block4])
        x_con = self.upsamp2(x_con)
        x_con = self.concat2([x_con, block3])
        x_con = self.upsamp3(x_con)
        x_con = self.convtrans(x_con)
        
        return x_con

# %%
### TableNet
tf.keras.backend.clear_session()
X_input = Input(shape = (1024,1024,3), name = "input_layer")

vgg_19 = tf.keras.applications.VGG19(include_top = False, weights = 'imagenet', input_tensor = X_input)

### extracting output of block 3 pool and block 4 pool

block3 = vgg_19.get_layer('block3_pool').output
block4 = vgg_19.get_layer('block4_pool').output

for layers in vgg_19.layers :
  layers.trainable = False  

X = Conv2D(kernel_size = 1, filters = 256, name = "block6_conv1", activation = 'relu', kernel_regularizer=tf.keras.regularizers.l2(0.004))(vgg_19.output)
X = Dropout(0.8)(X)
X = Conv2D(kernel_size = 1, filters = 256, name = "block6_conv2", activation = 'relu', kernel_regularizer=tf.keras.regularizers.l2(0.004))(X)
X = Dropout(0.8)(X)

X_comb = (X, block3, block4)

table_output = table_decoder()(X_comb)
column_output = column_decoder()(X_comb)
# Out:
# WARNING:tensorflow:Large dropout rate: 0.8 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.8 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.8 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.

# %%
model = Model(inputs = X_input, outputs = [column_output, table_output], name = "tablenet")

# %%
model.summary()
# Out:
# Model: "tablenet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_layer (InputLayer)        [(None, 1024, 1024,  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 1024, 1024, 6 1792        input_layer[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 1024, 1024, 6 36928       block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 512, 512, 64) 0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 512, 512, 128 73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 512, 512, 128 147584      block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 256, 256, 128 0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 256, 256, 256 295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 256, 256, 256 590080      block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 256, 256, 256 590080      block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv4 (Conv2D)           (None, 256, 256, 256 590080      block3_conv3[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 128, 128, 256 0           block3_conv4[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 128, 128, 512 1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 128, 128, 512 2359808     block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, 128, 128, 512 2359808     block4_conv2[0][0]
# __________________________________________________________________________________________________
# block4_conv4 (Conv2D)           (None, 128, 128, 512 2359808     block4_conv3[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 64, 64, 512)  0           block4_conv4[0][0]
# __________________________________________________________________________________________________
# block5_conv1 (Conv2D)           (None, 64, 64, 512)  2359808     block4_pool[0][0]
# __________________________________________________________________________________________________
# block5_conv2 (Conv2D)           (None, 64, 64, 512)  2359808     block5_conv1[0][0]
# __________________________________________________________________________________________________
# block5_conv3 (Conv2D)           (None, 64, 64, 512)  2359808     block5_conv2[0][0]
# __________________________________________________________________________________________________
# block5_conv4 (Conv2D)           (None, 64, 64, 512)  2359808     block5_conv3[0][0]
# __________________________________________________________________________________________________
# block5_pool (MaxPooling2D)      (None, 32, 32, 512)  0           block5_conv4[0][0]
# __________________________________________________________________________________________________
# block6_conv1 (Conv2D)           (None, 32, 32, 256)  131328      block5_pool[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 32, 32, 256)  0           block6_conv1[0][0]
# __________________________________________________________________________________________________
# block6_conv2 (Conv2D)           (None, 32, 32, 256)  65792       dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 32, 32, 256)  0           block6_conv2[0][0]
# __________________________________________________________________________________________________
# column_mask (column_decoder)    (None, 1024, 1024, 2 139778      dropout_1[0][0]
#                                                                  block3_pool[0][0]
#                                                                  block4_pool[0][0]
# __________________________________________________________________________________________________
# table_mask (table_decoder)      (None, 1024, 1024, 2 73986       dropout_1[0][0]
#                                                                  block3_pool[0][0]
#                                                                  block4_pool[0][0]
# ==================================================================================================
# Total params: 20,435,268
# Trainable params: 410,884
# Non-trainable params: 20,024,384
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model, to_file = "table_net.png", show_shapes = True, show_layer_names = True, rankdir = 'TB')

# %%
final_data = dataset.drop(['mask'], axis = 1)

# %%
final_data.head()
# Out:
#                                        image  ...                                       table_output
# 0   Case study 2/images/10.1.1.1.2006_3.jpeg  ...  Case study 2/output/10.1.1.1.2006_3/table_mask...
# 1  Case study 2/images/10.1.1.1.2013_63.jpeg  ...  Case study 2/output/10.1.1.1.2013_63/table_mas...
# 2  Case study 2/images/10.1.1.1.2013_64.jpeg  ...  Case study 2/output/10.1.1.1.2013_64/table_mas...
# 3   Case study 2/images/10.1.1.1.2014_4.jpeg  ...  Case study 2/output/10.1.1.1.2014_4/table_mask...
# 4   Case study 2/images/10.1.1.1.2014_6.jpeg  ...  Case study 2/output/10.1.1.1.2014_6/table_mask...
#
# [5 rows x 3 columns]

# %%
X_train , X_test = train_test_split(final_data, test_size = 0.10)

# %%
X_train.shape, X_test.shape
# Out:
# ((444, 3), (50, 3))

# %%
training_dataset = (tf.data.Dataset.from_tensor_slices((tf.cast(X_train['image'].values, tf.string),
                                                        tf.cast(X_train['column_output'].values, tf.string),
                                                        tf.cast(X_train['table_output'].values, tf.string),)))

# %%
testing_dataset = (tf.data.Dataset.from_tensor_slices((tf.cast(X_test['image'].values, tf.string),
                                                        tf.cast(X_test['column_output'].values, tf.string),
                                                        tf.cast(X_test['table_output'].values, tf.string),)))

# %%
train = training_dataset.map(load_image, num_parallel_calls=tf.data.AUTOTUNE)
test = testing_dataset.map(load_image)

# %%
BATCH_SIZE = 1
BUFFER_SIZE = 10
train_steps = len(X_train) // BATCH_SIZE
vaildation_steps = len(X_test) // BATCH_SIZE

train_dataset = train.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()
#train_dataset = train_dataset.prefetch(buffer_size = tf.data.experimental.AUTOTUNE)
test_dataset = test.batch(BATCH_SIZE)

# %%
train_dataset.take(1)
# Out:
# <TakeDataset shapes: ((None, 1024, 1024, 3), {column_mask: (None, 1024, 1024, 1), table_mask: (None, 1024, 1024, 1)}), types: (tf.float32, {column_mask: tf.float32, table_mask: tf.float32})>

# %%
model.load_weights('best_model_cs2_final_vgg.h5')

# %%
callbacks = [tf.keras.callbacks.ModelCheckpoint('best_model_cs2_final_vgg.h5', save_weights_only=True, save_best_only=True, mode = 'min', verbose=1),
             tf.keras.callbacks.ReduceLROnPlateau(factor = 0.2, patience=3, min_lr = 0.0000001, verbose=1)]

# %%
losses = {"column_mask" : tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
          "table_mask" : tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)}

loss_weights = {"column_mask" : 1.0, "table_mask" : 1.0}

optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001, epsilon=1e-08)
model.compile(optimizer = optimizer,loss = losses, metrics = ['accuracy'], loss_weights=loss_weights)

# %%
history = model.fit(train_dataset, steps_per_epoch=train_steps, epochs = 10, validation_data=test_dataset,validation_steps=vaildation_steps, callbacks=callbacks)
# Out:
# Epoch 1/10
# 444/444 [==============================] - 906s 2s/step - loss: 2.5174 - column_mask_loss: 0.4693 - table_mask_loss: 0.6578 - column_mask_accuracy: 0.8456 - table_mask_accuracy: 0.8021 - val_loss: 1.4358 - val_column_mask_loss: 0.3151 - val_table_mask_loss: 0.4074 - val_column_mask_accuracy: 0.8724 - val_table_mask_accuracy: 0.8593
#
# Epoch 00001: val_loss improved from inf to 1.43582, saving model to best_model_cs2_final_vgg.h5
# Epoch 2/10
# 444/444 [==============================] - 550s 1s/step - loss: 1.0966 - column_mask_loss: 0.2783 - table_mask_loss: 0.3906 - column_mask_accuracy: 0.8789 - table_mask_accuracy: 0.8515 - val_loss: 0.8701 - val_column_mask_loss: 0.2703 - val_table_mask_loss: 0.3545 - val_column_mask_accuracy: 0.8798 - val_table_mask_accuracy: 0.8710
#
# Epoch 00002: val_loss improved from 1.43582 to 0.87005, saving model to best_model_cs2_final_vgg.h5
# Epoch 3/10
# 444/444 [==============================] - 551s 1s/step - loss: 0.7572 - column_mask_loss: 0.2419 - table_mask_loss: 0.3442 - column_mask_accuracy: 0.8873 - table_mask_accuracy: 0.8677 - val_loss: 0.7349 - val_column_mask_loss: 0.2718 - val_table_mask_loss: 0.3398 - val_column_mask_accuracy: 0.8757 - val_table_mask_accuracy: 0.8752
#
# Epoch 00003: val_loss improved from 0.87005 to 0.73487, saving model to best_model_cs2_final_vgg.h5
# Epoch 4/10
# 444/444 [==============================] - 550s 1s/step - loss: 0.6515 - column_mask_loss: 0.2284 - table_mask_loss: 0.3227 - column_mask_accuracy: 0.8906 - table_mask_accuracy: 0.8745 - val_loss: 0.6407 - val_column_mask_loss: 0.2352 - val_table_mask_loss: 0.3211 - val_column_mask_accuracy: 0.8932 - val_table_mask_accuracy: 0.8868
#
# Epoch 00004: val_loss improved from 0.73487 to 0.64074, saving model to best_model_cs2_final_vgg.h5
# Epoch 5/10
# 444/444 [==============================] - 548s 1s/step - loss: 0.6085 - column_mask_loss: 0.2180 - table_mask_loss: 0.3163 - column_mask_accuracy: 0.8938 - table_mask_accuracy: 0.8761 - val_loss: 0.6170 - val_column_mask_loss: 0.2450 - val_table_mask_loss: 0.3054 - val_column_mask_accuracy: 0.8917 - val_table_mask_accuracy: 0.8913
#
# Epoch 00005: val_loss improved from 0.64074 to 0.61701, saving model to best_model_cs2_final_vgg.h5
# Epoch 6/10
# 444/444 [==============================] - 546s 1s/step - loss: 0.5758 - column_mask_loss: 0.2092 - table_mask_loss: 0.3062 - column_mask_accuracy: 0.8959 - table_mask_accuracy: 0.8800 - val_loss: 0.5748 - val_column_mask_loss: 0.2188 - val_table_mask_loss: 0.3001 - val_column_mask_accuracy: 0.8969 - val_table_mask_accuracy: 0.8933
#
# Epoch 00006: val_loss improved from 0.61701 to 0.57483, saving model to best_model_cs2_final_vgg.h5
# Epoch 7/10
# 444/444 [==============================] - 546s 1s/step - loss: 0.5483 - column_mask_loss: 0.2023 - table_mask_loss: 0.2944 - column_mask_accuracy: 0.8976 - table_mask_accuracy: 0.8841 - val_loss: 0.5464 - val_column_mask_loss: 0.2075 - val_table_mask_loss: 0.2903 - val_column_mask_accuracy: 0.8996 - val_table_mask_accuracy: 0.8943
#
# Epoch 00007: val_loss improved from 0.57483 to 0.54644, saving model to best_model_cs2_final_vgg.h5
# Epoch 8/10
# 444/444 [==============================] - 547s 1s/step - loss: 0.5324 - column_mask_loss: 0.1943 - table_mask_loss: 0.2925 - column_mask_accuracy: 0.9002 - table_mask_accuracy: 0.8844 - val_loss: 0.5461 - val_column_mask_loss: 0.2098 - val_table_mask_loss: 0.2926 - val_column_mask_accuracy: 0.8972 - val_table_mask_accuracy: 0.8924
#
# Epoch 00008: val_loss improved from 0.54644 to 0.54609, saving model to best_model_cs2_final_vgg.h5
# Epoch 9/10
# 444/444 [==============================] - 547s 1s/step - loss: 0.5207 - column_mask_loss: 0.1921 - table_mask_loss: 0.2871 - column_mask_accuracy: 0.9005 - table_mask_accuracy: 0.8871 - val_loss: 0.5285 - val_column_mask_loss: 0.2015 - val_table_mask_loss: 0.2868 - val_column_mask_accuracy: 0.9020 - val_table_mask_accuracy: 0.8955
#
# Epoch 00009: val_loss improved from 0.54609 to 0.52853, saving model to best_model_cs2_final_vgg.h5
# Epoch 10/10
# 444/444 [==============================] - 547s 1s/step - loss: 0.5130 - column_mask_loss: 0.1890 - table_mask_loss: 0.2857 - column_mask_accuracy: 0.9026 - table_mask_accuracy: 0.8882 - val_loss: 0.5340 - val_column_mask_loss: 0.2113 - val_table_mask_loss: 0.2854 - val_column_mask_accuracy: 0.8987 - val_table_mask_accuracy: 0.8970
#
# Epoch 00010: val_loss did not improve from 0.52853

# %%
plt.figure(figsize = (30,5))
plt.subplot(121)
plt.plot(history.history['val_table_mask_accuracy'])
plt.plot(history.history['table_mask_accuracy'])
plt.title('Table mask accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Test', 'Train'], loc = 'upper left')

plt.subplot(122)
plt.plot(history.history['val_column_mask_accuracy'])
plt.plot(history.history['column_mask_accuracy'])
plt.title('Column mask accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Test', 'Train'], loc = 'upper left')

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc = 'upper left')

# %%
def create_mask(col_pred_mask, table_pred_mask):
  col_pred_mask = tf.argmax(col_pred_mask, axis = -1)
  col_pred_mask = col_pred_mask[..., np.newaxis]
  table_pred_mask = tf.argmax(table_pred_mask, axis = -1)
  table_pred_mask = table_pred_mask[..., np.newaxis]
  return col_pred_mask[0], table_pred_mask[0]

# %%
number = 2

for image, mask in test.take(number) :
  image = image[np.newaxis, ...]
  col_mask, tab_mask = model.predict(image)
  col_mask, tab_mask = create_mask(col_mask, tab_mask)
  plt.figure(figsize = (10,6))
  plt.subplot(131)
  plt.title('Image')
  image = tf.squeeze(image)
  plt.imshow(image)
  plt.subplot(132)
  plt.title('Column Mask')
  plt.imshow(tf.keras.preprocessing.image.array_to_img(col_mask))
  plt.subplot(133)
  plt.title('Table Mask')
  plt.imshow(tf.keras.preprocessing.image.array_to_img(tab_mask))
  plt.show()

# %% [markdown]
# # Precision, Recall and F1

# %%
table_mask = []
column_mask = []
pred_table_mask = []
pred_column_mask = []

# %%
for image, mask in test :
  table_mask.append(mask['table_mask'])
  column_mask.append(mask['column_mask'])
  col, tab = model.predict(image[np.newaxis,:,:,:])
  col_mask, tab_mask = create_mask(col, tab)
  pred_column_mask.append(col_mask)
  pred_table_mask.append(tab_mask)

# %%
def precision(mask, predicted_mask):
  m = tf.keras.metrics.Precision()
  m.update_state(mask, predicted_mask)
  return m.result().numpy()

# %%
p1 = precision(column_mask, pred_column_mask)

# %%
print ("*"*100)
print ("Precision for test points for column mask is {}".format(p1))
print ("*"*100)
# Out:
# ****************************************************************************************************
# Precision for test points for column mask is 0.8567249178886414
# ****************************************************************************************************

# %%
p2 = precision(table_mask, pred_table_mask)

# %%
print ("*"*100)
print ("Precision for test points for table mask is {}".format(p2))
print ("*"*100)
# Out:
# ****************************************************************************************************
# Precision for test points for table mask is 0.8059242367744446
# ****************************************************************************************************

# %%
def recall(mask, predicted_mask):
  m = tf.keras.metrics.Recall()
  m.update_state(mask, predicted_mask)
  return m.result().numpy()

# %%
r1 = recall(column_mask, pred_column_mask)
print ("*"*100)
f1 = 2*(r1*p1)/(r1+p1)
print ("F1 score for test points for column mask is {}".format(f1))
r2 = recall(table_mask, pred_table_mask)
f2 = 2*(p2*r2)/(p2+r2)
print ("F1 score for test points for table mask is {}".format(f2))
print ("*"*100)
# Out:
# ****************************************************************************************************
# F1 score for test points for column mask is 0.5091760345776548
# F1 score for test points for table mask is 0.6521103470749746
# ****************************************************************************************************

# %%
for image, mask in test.take(1):
  col , tab = model.predict(image[np.newaxis, :, :, :])
  col_mask, tab_mask = create_mask(col, tab)

  im = tf.keras.preprocessing.image.array_to_img(image)
  im.save("original_image.bmp")

  im = tf.keras.preprocessing.image.array_to_img(col_mask)
  im.save("col_mask.bmp")

  im = tf.keras.preprocessing.image.array_to_img(tab_mask)
  im.save("tab_mask.bmp")

# %% [markdown]
# ## Calculating Precision and Recall for all the 494 files

# %%
for image, mask in test :
  table_mask.append(mask['table_mask'])
  column_mask.append(mask['column_mask'])
  col, tab = model.predict(image[np.newaxis,:,:,:])
  col_mask, tab_mask = create_mask(col, tab)
  pred_column_mask.append(col_mask)
  pred_table_mask.append(tab_mask)

for image, mask in train :
  table_mask.append(mask['table_mask'])
  column_mask.append(mask['column_mask'])
  col, tab = model.predict(image[np.newaxis,:,:,:])
  col_mask, tab_mask = create_mask(col, tab)
  pred_column_mask.append(col_mask)
  pred_table_mask.append(tab_mask)

# %%
pr = []
for i,j in zip(column_mask, pred_column_mask):
  p = precision(i,j)
  pr.append(p)

# %%
df = pd.DataFrame()
df['precision_column'] = pr
hist = df.hist(bins = 5)

# %%
df['precision_column'].describe()
# Out:
# count    494.000000
# mean       0.792706
# std        0.149976
# min        0.014214
# 25%        0.724310
# 50%        0.832780
# 75%        0.899981
# max        0.995711
# Name: precision_column, dtype: float64

# %% [markdown]
# ### Observation - About 75% of the column masks have precision around 0.9

# %%
pr_table = []
for i,j in zip(table_mask, pred_table_mask):
  p = precision(i,j)
  pr_table.append(p)

df['precision_table'] = pr_table
hist = df.precision_table.hist(bins = 5)

# %%
df['precision_table'].describe()
# Out:
# count    494.000000
# mean       0.752939
# std        0.221568
# min        0.000000
# 25%        0.656813
# 50%        0.826130
# 75%        0.916957
# max        0.996727
# Name: precision_table, dtype: float64

# %% [markdown]
# ### Observation - Around 75 % of the table masks have precision around 0.91

# %%
recall_column = []
for i,j in zip(column_mask, pred_column_mask):
  r = recall(i,j)
  recall_column.append(r)

# %%
df['recall_column'] = recall_column
hist = df['recall_column'].hist(bins = 5)

# %%
df['recall_column'].describe()
# Out:
# count    494.000000
# mean       0.559547
# std        0.188536
# min        0.000373
# 25%        0.438394
# 50%        0.591171
# 75%        0.712059
# max        0.890295
# Name: recall_column, dtype: float64

# %% [markdown]
# ### Observation - 75% of the column masks have recall around 0.71

# %%
recall_table = []
for i,j in zip(table_mask, pred_table_mask):
  r = recall(i,j)
  recall_table.append(r)

df['recall_table'] = recall_table
hist = df['recall_table'].hist(bins = 5)

# %%
df['recall_table'].describe()
# Out:
# count    494.000000
# mean       0.712934
# std        0.257979
# min        0.000000
# 25%        0.547450
# 50%        0.790431
# 75%        0.939142
# max        0.997788
# Name: recall_table, dtype: float64

# %% [markdown]
# ### Observation - Around 75 % of the table masks have recall around 0.93

# %% [markdown]
# ## Extracting textual data from the image

# %%
os.chdir("D:/Applied AI/")

# %%
img = Image.open("original_image.bmp")

# %%
img
# Out:
# <PIL.BmpImagePlugin.BmpImageFile image mode=RGB size=1024x1024 at 0x1D7850F1D88>

# %%
table_mask = Image.open("tab_mask.bmp")

# %%
img.putalpha(table_mask)

# %%
img.save("output_alpha.png")

# %%
image = cv2.imread("output_alpha.png", cv2.IMREAD_UNCHANGED)
plt.figure(figsize = (40,20))
plt.imshow(image)

# %%
pytesseract.pytesseract.tesseract_cmd = r"C:/Program Files/Tesseract-OCR/tesseract.exe"

# %%
def image_to_text(img_name):
    text = pytesseract.image_to_string(Image.open(img_name))
    return text

# %%
print (image_to_text("output_alpha.png"))
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# eee “ __.
# Bo temact age |
# Mem | Timi | gs | mobuse | Slope | Shape
# ods) | omg | Simplysit | mess ee
# i tee | vem
# Meiko 5
# so loos | Emy yes | yes | No
# Mews Positie
# fee Tis | cay ves | No =
# Weiho Poaitie
# “emo Tas | nara ves | No
# Meta Positiy
# “emo | 126 | Hard yes | vee “
# Memo Positis
# terme | 2ats | Trivial no | vee [Pos
#
#
#
#
#
# Fai] a
#
# y
# fay €
#
# 94

# %%
tf_lite_converter = tf.lite.TFLiteConverter.from_keras_model(model)
tf_lite_converter.optimizations = [tf.lite.Optimize.OPTIMIZE_FOR_SIZE]
tflite_model = tf_lite_converter.convert()

# %%
open("vgg_compressed.tflite", "wb").write(tflite_model)
# Out:
# 20518192
